# %%
import pandas as pd

df = pd.read_csv("clean_churn.csv")

df.head()
# Out:
# Running cells with '.venv (3.13.12.final.0) (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"e:/semester-V/Machine learning LAB/LAB_3/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
